# %%
# %pip install -U azure-ai-projects azure-identity azure-functions
# Out:
# Requirement already satisfied: azure-ai-projects in c:\users\aidan\anaconda3\envs\langchain-rag\lib\site-packages (1.0.0b12)
# Requirement already satisfied: azure-identity in c:\users\aidan\anaconda3\envs\langchain-rag\lib\site-packages (1.23.0)
# Collecting azure-functions
#   Downloading azure_functions-1.23.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\aidan\anaconda3\envs\langchain-rag\lib\site-packages (from azure-ai-projects) (0.7.2)
# Requirement already satisfied: azure-core>=1.30.0 in c:\users\aidan\anaconda3\envs\langchain-rag\lib\site-packages (from azure-ai-projects) (1.34.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\aidan\anaconda3\envs\langchain-rag\lib\site-packages (from azure-ai-projects) (4.12.2)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in c:\users\aidan\anaconda3\envs\langchain-rag\lib\site-packages (from azure-ai-projects) (12.25.1)
# Requirement already satisfied: azure-ai-agents>=1.0.0 in c:\users\aidan\anaconda3\envs\langchain-rag\lib\site-packages (from azure-ai-projects) (1.0.2)
# Requirement already satisfied: cryptography>=2.5 in c:\users\aidan\anaconda3\envs\langchain-rag\lib\site-packages (from azure-identity) (45.0.4)
# Requirement already satisfied: msal>=1.30.0 in c:\users\aidan\anaconda3\envs\langchain-rag\lib\site-packages (from azure-identity) (1.32.3)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\aidan\anaconda3\envs\langchain-rag\lib\site-packages (from azure-identity) (1.3.1)
# Collecting werkzeug~=3.1.3 (from azure-functions)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug~=3.1.3->azure-functions)
#   Downloading MarkupSafe-3.0.2-cp311-cp311-win_amd64.whl.metadata (4.1 kB)
# Requirement already satisfied: requests>=2.21.0 in c:\users\aidan\anaconda3\envs\langchain-rag\lib\site-packages (from azure-core>=1.30.0->azure-ai-projects) (2.32.4)
# Requirement already satisfied: six>=1.11.0 in c:\users\aidan\anaconda3\envs\langchain-rag\lib\site-packages (from azure-core>=1.30.0->azure-ai-projects) (1.17.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\aidan\anaconda3\envs\langchain-rag\lib\site-packages (from cryptography>=2.5->azure-identity) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\aidan\anaconda3\envs\langchain-rag\lib\site-packages (from cffi>=1.14->cryptography>=2.5->azure-identity) (2.21)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\aidan\anaconda3\envs\langchain-rag\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.10.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\aidan\anaconda3\envs\langchain-rag\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-projects) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aidan\anaconda3\envs\langchain-rag\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-projects) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aidan\anaconda3\envs\langchain-rag\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-projects) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aidan\anaconda3\envs\langchain-rag\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-ai-projects) (2025.6.15)
# Downloading azure_functions-1.23.0-py3-none-any.whl (137 kB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading MarkupSafe-3.0.2-cp311-cp311-win_amd64.whl (15 kB)
# Installing collected packages: MarkupSafe, werkzeug, azure-functions
#
#    ------------- -------------------------- 1/3 [werkzeug]
#    ------------- -------------------------- 1/3 [werkzeug]
#    -------------------------- ------------- 2/3 [azure-functions]
#    -------------------------- ------------- 2/3 [azure-functions]
#    -------------------------- ------------- 2/3 [azure-functions]
#    ---------------------------------------- 3/3 [azure-functions]
#
# Successfully installed MarkupSafe-3.0.2 azure-functions-1.23.0 werkzeug-3.1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from azure.ai.agents.models import AzureFunctionStorageQueue, AzureFunctionTool, MessageRole
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient  # Import AIProjectClient for consistency

azure_ai_foundry_resource_name = ""
azure_ai_foundry_project_name = ""
project_endpoint = f"https://{azure_ai_foundry_resource_name}.services.ai.azure.com/api/projects/{azure_ai_foundry_project_name}"

# Initialize the AIProjectClient
project_client = AIProjectClient(
    endpoint=project_endpoint,
    credential=DefaultAzureCredential(),
)


# Use the project client within a context manager to ensure proper resource cleanup
with project_client:
    # Retrieve the storage service endpoint from environment variables
    storage_account_name = ""
    storage_service_endpoint = f"https://{storage_account_name}.queue.core.windows.net/"  # Replace with your actual storage account endpoint

    # [START create_agent_with_azure_function_tool]
    # Define an Azure Function Tool with input and output queue configurations
    azure_function_tool = AzureFunctionTool(
        name="foo",  # Name of the tool
        description="Get answers from the foo bot.",  # Description of the tool's purpose
        parameters={  # Define the parameters required by the tool
            "type": "object",
            "properties": {
                "query": {"type": "string", "description": "The question to ask."},
                "outputqueueuri": {"type": "string", "description": "The full output queue uri."},
            },
        },
        input_queue=AzureFunctionStorageQueue(  # Input queue configuration
            queue_name="azure-function-foo-input",
            storage_service_endpoint=storage_service_endpoint,
        ),
        output_queue=AzureFunctionStorageQueue(  # Output queue configuration
            queue_name="azure-function-tool-output",
            storage_service_endpoint=storage_service_endpoint,
        ),
    )

    # Create an agent with the Azure Function Tool
    agent = project_client.agents.create_agent(
        model="gpt-4.1",  # Model deployment name from environment variables
        name="azure-function-agent-foo",  # Name of the agent
        instructions=(
            "You are a helpful support agent. Use the provided function any time the prompt contains the string "
            "'What would foo say?'. When you invoke the function, ALWAYS specify the output queue uri parameter as "
            f"'{storage_service_endpoint}/azure-function-tool-output'. Always responds with \"Foo says\" and then the response from the tool."
        ),
        tools=azure_function_tool.definitions,  # Attach the tool definitions to the agent
    )
    print(f"Created agent, agent ID: {agent.id}")
    # [END create_agent_with_azure_function_tool]

    # Create a new thread for the agent to interact with
    thread = project_client.agents.threads.create()
    print(f"Created thread, thread ID: {thread.id}")

    # Create a user message in the thread
    message = project_client.agents.messages.create(
        thread_id=thread.id,  # ID of the thread
        role="user",  # Role of the message sender
        content="What is the most prevalent element in the universe? What would foo say?",  # Message content
    )
    print(f"Created message, message ID: {message['id']}")

    # Create and process a run for the agent to handle the message
    run = project_client.agents.runs.create_and_process(thread_id=thread.id, agent_id=agent.id)
    print(f"Run finished with status: {run.status}")

    # Check if the run failed and log the error if applicable
    if run.status == "failed":
        print(f"Run failed: {run.last_error}")

    # Retrieve and print all messages from the thread
    messages = project_client.agents.messages.list(thread_id=thread.id)
    for msg in messages:
        print(f"Role: {msg['role']}, Content: {msg['content']}")

    # Delete the agent after the interaction is complete
    project_client.agents.delete_agent(agent.id)
    print(f"Deleted agent {agent.id}")
# Out:
# ---------------------------------------------------------------------------
# ServiceRequestError                       Traceback (most recent call last)
# Cell In[6], line 46
#      25 azure_function_tool = AzureFunctionTool(
#      26     name="foo",  # Name of the tool
#      27     description="Get answers from the foo bot.",  # Description of the tool's purpose
#    (...)
#      42     ),
#      43 )
#      45 # Create an agent with the Azure Function Tool
# ---> 46 agent = project_client.agents.create_agent(
#      47     model="gpt-4.1",  # Model deployment name from environment variables
#      48     name="azure-function-agent-foo",  # Name of the agent
#      49     instructions=(
#      50         "You are a helpful support agent. Use the provided function any time the prompt contains the string "
#      51         "'What would foo say?'. When you invoke the function, ALWAYS specify the output queue uri parameter as "
#      52         f"'{storage_service_endpoint}/azure-function-tool-output'. Always responds with \"Foo says\" and then the response from the tool."
#      53     ),
#      54     tools=azure_function_tool.definitions,  # Attach the tool definitions to the agent
#      55 )
#      56 print(f"Created agent, agent ID: {agent.id}")
#      57 # [END create_agent_with_azure_function_tool]
#      58
#      59 # Create a new thread for the agent to interact with
#
# File ~/Desktop/personal/jhj_jupyter_test/venv/lib/python3.11/site-packages/azure/core/tracing/decorator.py:119, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     117 # If tracing is disabled globally and user didn't explicitly enable it, don't trace.
#     118 if user_enabled is False or (not tracing_enabled and user_enabled is None):
# --> 119     return func(*args, **kwargs)
#     121 # Merge span is parameter is set, but only if no explicit parent are passed
#     122 if merge_span and not passed_in_parent:
#
# File ~/Desktop/personal/jhj_jupyter_test/venv/lib/python3.11/site-packages/azure/ai/agents/_patch.py:294, in AgentsClient.create_agent(self, body, model, name, description, instructions, tools, tool_resources, toolset, temperature, top_p, response_format, metadata, content_type, **kwargs)
#     291     tools = toolset.definitions
#     292     tool_resources = toolset.resources
# --> 294 new_agent = super().create_agent(
#     295     model=model,
#     296     name=name,
#     297     description=description,
#     298     instructions=instructions,
#     299     tools=tools,
#     300     tool_resources=tool_resources,
#     301     temperature=temperature,
#     302     top_p=top_p,
#     303     response_format=response_format,
#     304     metadata=metadata,
#     305     **kwargs,
#     306 )
#     308 return new_agent
#
# File ~/Desktop/personal/jhj_jupyter_test/venv/lib/python3.11/site-packages/azure/core/tracing/decorator.py:119, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     117 # If tracing is disabled globally and user didn't explicitly enable it, don't trace.
#     118 if user_enabled is False or (not tracing_enabled and user_enabled is None):
# --> 119     return func(*args, **kwargs)
#     121 # Merge span is parameter is set, but only if no explicit parent are passed
#     122 if merge_span and not passed_in_parent:
#
# File ~/Desktop/personal/jhj_jupyter_test/venv/lib/python3.11/site-packages/azure/ai/agents/operations/_operations.py:5296, in AgentsClientOperationsMixin.create_agent(self, body, model, name, description, instructions, tools, tool_resources, temperature, top_p, response_format, metadata, **kwargs)
#    5293 _request.url = self._client.format_url(_request.url, **path_format_arguments)
#    5295 _stream = kwargs.pop("stream", False)
# -> 5296 pipeline_response: PipelineResponse = self._client._pipeline.run(  # pylint: disable=protected-access
#    5297     _request, stream=_stream, **kwargs
#    5298 )
#    5300 response = pipeline_response.http_response
#    5302 if response.status_code not in [200]:
#
# File ~/Desktop/personal/jhj_jupyter_test/venv/lib/python3.11/site-packages/azure/core/pipeline/_base.py:242, in Pipeline.run(self, request, **kwargs)
#     240 pipeline_request: PipelineRequest[HTTPRequestType] = PipelineRequest(request, context)
#     241 first_node = self._impl_policies[0] if self._impl_policies else _TransportRunner(self._transport)
# --> 242 return first_node.send(pipeline_request)
#
# File ~/Desktop/personal/jhj_jupyter_test/venv/lib/python3.11/site-packages/azure/core/pipeline/_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
# File ~/Desktop/personal/jhj_jupyter_test/venv/lib/python3.11/site-packages/azure/core/pipeline/_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
#     [... skipping similar frames: _SansIOHTTPPolicyRunner.send at line 98 (2 times)]
#
# File ~/Desktop/personal/jhj_jupyter_test/venv/lib/python3.11/site-packages/azure/core/pipeline/_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
# File ~/Desktop/personal/jhj_jupyter_test/venv/lib/python3.11/site-packages/azure/core/pipeline/policies/_redirect.py:205, in RedirectPolicy.send(self, request)
#     203 original_domain = get_domain(request.http_request.url) if redirect_settings["allow"] else None
#     204 while retryable:
# --> 205     response = self.next.send(request)
#     206     redirect_location = self.get_redirect_location(response)
#     207     if redirect_location and redirect_settings["allow"]:
#
# File ~/Desktop/personal/jhj_jupyter_test/venv/lib/python3.11/site-packages/azure/core/pipeline/policies/_retry.py:566, in RetryPolicy.send(self, request)
#     564                 is_response_error = True
#     565             continue
# --> 566     raise err
#     567 finally:
#     568     end_time = time.time()
#
# File ~/Desktop/personal/jhj_jupyter_test/venv/lib/python3.11/site-packages/azure/core/pipeline/policies/_retry.py:544, in RetryPolicy.send(self, request)
#     542 self._configure_timeout(request, absolute_timeout, is_response_error)
#     543 request.context["retry_count"] = len(retry_settings["history"])
# --> 544 response = self.next.send(request)
#     545 if self.is_retry(retry_settings, response):
#     546     retry_active = self.increment(retry_settings, response=response)
#
# File ~/Desktop/personal/jhj_jupyter_test/venv/lib/python3.11/site-packages/azure/core/pipeline/policies/_authentication.py:159, in BearerTokenCredentialPolicy.send(self, request)
#     157 self.on_request(request)
#     158 try:
# --> 159     response = self.next.send(request)
#     160 except Exception:
#     161     self.on_exception(request)
#
# File ~/Desktop/personal/jhj_jupyter_test/venv/lib/python3.11/site-packages/azure/core/pipeline/_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
# File ~/Desktop/personal/jhj_jupyter_test/venv/lib/python3.11/site-packages/azure/core/pipeline/_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
#     [... skipping similar frames: _SansIOHTTPPolicyRunner.send at line 98 (2 times)]
#
# File ~/Desktop/personal/jhj_jupyter_test/venv/lib/python3.11/site-packages/azure/core/pipeline/_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
# File ~/Desktop/personal/jhj_jupyter_test/venv/lib/python3.11/site-packages/azure/core/pipeline/_base.py:130, in _TransportRunner.send(self, request)
#     120 """HTTP transport send method.
#     121
#     122 :param request: The PipelineRequest object.
#    (...)
#     125 :rtype: ~azure.core.pipeline.PipelineResponse
#     126 """
#     127 cleanup_kwargs_for_transport(request.context.options)
#     128 return PipelineResponse(
#     129     request.http_request,
# --> 130     self._sender.send(request.http_request, **request.context.options),
#     131     context=request.context,
#     132 )
#
# File ~/Desktop/personal/jhj_jupyter_test/venv/lib/python3.11/site-packages/azure/core/pipeline/transport/_requests_basic.py:409, in RequestsTransport.send(self, request, proxies, **kwargs)
#     406     error = ServiceRequestError(err, error=err)
#     408 if error:
# --> 409     raise error
#     410 if _is_rest(request):
#     411     from azure.core.rest._requests_basic import RestRequestsTransportResponse
#
# ServiceRequestError: URL has an invalid label.
