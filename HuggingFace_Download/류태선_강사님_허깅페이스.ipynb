# %%
# 1 허깅페이스 토큰을 직접 코드상에 입력해서 사용하는 방법
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# ...

# %%
from transformers import pipeline

# %%
# !pip install --upgrade transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 44.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.48.3
#     Uninstalling transformers-4.48.3:
#       Successfully uninstalled transformers-4.48.3
# ...

# %%
generator = pipeline('text-generation', model='skt/ko-gpt-trinity-1.2B-v0.5')
# Out:
# Device set to use cpu

# %%
# prompt: generator("안녕하세요 오늘은 딥러", max_length=50)

generated_text = generator("안녕하세요 오늘은 딥러", max_length=50)
generated_text
# Out:
# [{'generated_text': '안녕하세요 오늘은 딥러닝에 대해서 알아보도록 하겠습니다. 딥러닝은 인공지능을 뜻합니다. 인공지능은 컴퓨터가 스스로 학습하는 것을 말합니다. 인공지능은 컴퓨터가 스스로 학습하는 것을 말합니다. 인공지능은 컴퓨터가 스스로 학습하는 것을 말'}]

# %%
from transformers import AutoModel, AutoTokenizer

# %%
model_name = 'klue/roberta-large'

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/375 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/752k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/173 [00:00<?, ?B/s]

# %%
model = AutoModel.from_pretrained(model_name)
# Out:
# config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.35G [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# fine-tuning을 위해 로컬로 다운
model.save_pretrained('./my_model')
tokenizer.save_pretrained('./my_model')
# Out:
# ('./my_model/tokenizer_config.json',
#  './my_model/special_tokens_map.json',
#  './my_model/vocab.txt',
#  './my_model/added_tokens.json',
#  './my_model/tokenizer.json')

# %%
# !pip install datasets
from datasets import load_dataset
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 487.4/487.4 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 10.5 MB/s eta 0:00:00
# ...

# %%
dataset = load_dataset('klue', 'sts')
# Out:
# README.md:   0%|          | 0.00/22.5k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/1.52M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/68.8k [00:00<?, ?B/s]
# ...
# Generating validation split:   0%|          | 0/519 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['guid', 'source', 'sentence1', 'sentence2', 'labels'],
#         num_rows: 11668
#     })
#     validation: Dataset({
#         features: ['guid', 'source', 'sentence1', 'sentence2', 'labels'],
#         num_rows: 519
#     })
# })

# %%
dataset['train'][0]
# Out:
# {'guid': 'klue-sts-v1_train_00000',
#  'source': 'airbnb-rtt',
#  'sentence1': '숙소 위치는 찾기 쉽고 일반적인 한국의 반지하 숙소입니다.',
#  'sentence2': '숙박시설의 위치는 쉽게 찾을 수 있고 한국의 대표적인 반지하 숙박시설입니다.',
#  'labels': {'label': 3.7, 'real-label': 3.714285714285714, 'binary-label': 1}}
